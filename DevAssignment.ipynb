# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashbd/DataVisualisation/blob/main/DevAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("STUDENT_DATASET.csv")
display(df)
# Out:
#     age     sex  Marks Section name      City  percentage  s.no
# 0    19  female    300       A  AAA  Banglore       75.00     1
# 1    18    male    330       B  BBB      Pune       82.50     2
# 2    28    male    324       C  CDC    Mumbai       81.00     3
# 3    33    male    322       D  SDC     Delhi       80.50     4
# 4    32    male    240       A  SFG    Mumbai       60.00     5
# ..  ...     ...    ...     ...  ...       ...         ...   ...
# 94   64  female    356       C  NMB      Pune       89.00    95
# 95   28  female    344       D  FDT     Delhi       86.00    96
# 96   54  female    245       A  TAM      Pune       61.25    97
# 97   55    male    388       B  GQP  Banglore       97.00    98
# 98   56    male    365       C  KKK      Pune       91.25    99
#
# [99 rows x 8 columns]

# %%
plt.scatter(x=df['s.no'],y=df['percentage'])

# %%
x=df['s.no']
y=df['percentage']
fig=plt.figure(figsize=(5,6))
plt.bar(x,y,color='blue')
# Out:
# <BarContainer object of 99 artists>

# %%
x=df['s.no']
y=df['percentage']
fig=plt.figure(figsize=(5,6))
plt.plot(x,y)

# %%
x=df['name']
y=df['Marks']
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb5c64f29d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c65a1110>,
#   <matplotlib.patches.Wedge at 0x7fb5c64fe350>,
#   <matplotlib.patches.Wedge at 0x7fb5c64fe410>,
#   <matplotlib.patches.Wedge at 0x7fb5c6508290>,
#   <matplotlib.patches.Wedge at 0x7fb5c6508250>,
#   <matplotlib.patches.Wedge at 0x7fb5c6508610>,
#   <matplotlib.patches.Wedge at 0x7fb5c65121d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64fe9d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6508650>,
#   <matplotlib.patches.Wedge at 0x7fb5c64f2990>,
#   <matplotlib.patches.Wedge at 0x7fb5c65202d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6520850>,
#   <matplotlib.patches.Wedge at 0x7fb5c652a350>,
#   <matplotlib.patches.Wedge at 0x7fb5c652a410>,
#   <matplotlib.patches.Wedge at 0x7fb5c652a9d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64b64d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64b6590>,
#   <matplotlib.patches.Wedge at 0x7fb5c64c3090>,
#   <matplotlib.patches.Wedge at 0x7fb5c64c3150>,
#   <matplotlib.patches.Wedge at 0x7fb5c64c3710>,
#   <matplotlib.patches.Wedge at 0x7fb5c64ce210>,
#   <matplotlib.patches.Wedge at 0x7fb5c64ce2d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64ce890>,
#   <matplotlib.patches.Wedge at 0x7fb5c64da390>,
#   <matplotlib.patches.Wedge at 0x7fb5c64da450>,
#   <matplotlib.patches.Wedge at 0x7fb5c64daa10>,
#   <matplotlib.patches.Wedge at 0x7fb5c64e5510>,
#   <matplotlib.patches.Wedge at 0x7fb5c64e55d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64700d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6470190>,
#   <matplotlib.patches.Wedge at 0x7fb5c6470750>,
#   <matplotlib.patches.Wedge at 0x7fb5c647e250>,
#   <matplotlib.patches.Wedge at 0x7fb5c647e310>,
#   <matplotlib.patches.Wedge at 0x7fb5c647e8d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64893d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6489490>,
#   <matplotlib.patches.Wedge at 0x7fb5c6489a50>,
#   <matplotlib.patches.Wedge at 0x7fb5c6493050>,
#   <matplotlib.patches.Wedge at 0x7fb5c6493610>,
#   <matplotlib.patches.Wedge at 0x7fb5c649e110>,
#   <matplotlib.patches.Wedge at 0x7fb5c649e1d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c649e790>,
#   <matplotlib.patches.Wedge at 0x7fb5c64ab290>,
#   <matplotlib.patches.Wedge at 0x7fb5c64ab350>,
#   <matplotlib.patches.Wedge at 0x7fb5c64ab910>,
#   <matplotlib.patches.Wedge at 0x7fb5c6437410>,
#   <matplotlib.patches.Wedge at 0x7fb5c64374d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6437a90>,
#   <matplotlib.patches.Wedge at 0x7fb5c6443090>,
#   <matplotlib.patches.Wedge at 0x7fb5c6443650>,
#   <matplotlib.patches.Wedge at 0x7fb5c644d150>,
#   <matplotlib.patches.Wedge at 0x7fb5c644d210>,
#   <matplotlib.patches.Wedge at 0x7fb5c644d7d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64592d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6459390>,
#   <matplotlib.patches.Wedge at 0x7fb5c6459950>,
#   <matplotlib.patches.Wedge at 0x7fb5c6466450>,
#   <matplotlib.patches.Wedge at 0x7fb5c6466510>,
#   <matplotlib.patches.Wedge at 0x7fb5c6466ad0>,
#   <matplotlib.patches.Wedge at 0x7fb5c63f00d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c63f0690>,
#   <matplotlib.patches.Wedge at 0x7fb5c63fb190>,
#   <matplotlib.patches.Wedge at 0x7fb5c63fb250>,
#   <matplotlib.patches.Wedge at 0x7fb5c63fb810>,
#   <matplotlib.patches.Wedge at 0x7fb5c6407310>,
#   <matplotlib.patches.Wedge at 0x7fb5c64073d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6407990>,
#   <matplotlib.patches.Wedge at 0x7fb5c6412490>,
#   <matplotlib.patches.Wedge at 0x7fb5c6412550>,
#   <matplotlib.patches.Wedge at 0x7fb5c641e050>,
#   <matplotlib.patches.Wedge at 0x7fb5c641e110>,
#   <matplotlib.patches.Wedge at 0x7fb5c641e6d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c64291d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c6429290>,
#   <matplotlib.patches.Wedge at 0x7fb5c6429850>,
#   <matplotlib.patches.Wedge at 0x7fb5c63b5350>,
#   <matplotlib.patches.Wedge at 0x7fb5c63b5410>,
#   <matplotlib.patches.Wedge at 0x7fb5c63b59d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c63c04d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c63c0590>,
#   <matplotlib.patches.Wedge at 0x7fb5c63cc090>,
#   <matplotlib.patches.Wedge at 0x7fb5c63cc150>,
#   <matplotlib.patches.Wedge at 0x7fb5c63cc710>,
#   <matplotlib.patches.Wedge at 0x7fb5c63d8210>,
#   <matplotlib.patches.Wedge at 0x7fb5c63d82d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c63d8890>,
#   <matplotlib.patches.Wedge at 0x7fb5c63e3390>,
#   <matplotlib.patches.Wedge at 0x7fb5c63e3450>,
#   <matplotlib.patches.Wedge at 0x7fb5c63e3a10>,
#   <matplotlib.patches.Wedge at 0x7fb5c636e510>,
#   <matplotlib.patches.Wedge at 0x7fb5c636e5d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c637a0d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c637a190>,
#   <matplotlib.patches.Wedge at 0x7fb5c637a750>,
#   <matplotlib.patches.Wedge at 0x7fb5c6386250>,
#   <matplotlib.patches.Wedge at 0x7fb5c6386310>,
#   <matplotlib.patches.Wedge at 0x7fb5c63868d0>,
#   <matplotlib.patches.Wedge at 0x7fb5c63923d0>],
#  [Text(1.099485879485182, 0.03362738188880777, 'AAA'),
#   Text(1.095062615028819, 0.10410508712951881, 'BBB'),
#   Text(1.0856971301037568, 0.17680990267648058, 'CDC'),
#   Text(1.0717124226477461, 0.24785577084768268, 'SDC'),
#   Text(1.055766154024097, 0.30880062826549853, 'SFG'),
#   Text(1.0390350274392786, 0.36111800253415477, 'DFG'),
#   Text(1.013287588181027, 0.42807506776064136, 'SDS'),
#   Text(0.9807045071286777, 0.49821548520444203, 'AAB'),
#   Text(0.9470016508487232, 0.5596319087487714, 'BBC'),
#   Text(0.9087634022342799, 0.6197976111276783, 'HHH'),
#   Text(0.8669153529633123, 0.6770950973064979, 'FGF'),
#   Text(0.8156941046955937, 0.7379994089190411, 'HJI'),
#   Text(0.7602846661062767, 0.7949636636247392, 'KOJ'),
#   Text(0.7141264169528441, 0.8366740468127912, 'KLO'),
#   Text(0.6720031813174299, 0.8708683736933233, 'PLK'),
#   Text(0.6313702208125009, 0.900761702267128, 'PLI'),
#   Text(0.5865670301086041, 0.9305584985317001, 'PLY'),
#   Text(0.5324324124800272, 0.962556869042395, 'PLT'),
#   Text(0.476961856558906, 0.9912151065171887, 'OIU'),
#   Text(0.4236820417270833, 1.0151322709469788, 'POI'),
#   Text(0.366566618228863, 1.037125312775778, 'PLO'),
#   Text(0.3129408627473319, 1.0545463557487436, 'DFT'),
#   Text(0.2536956389619697, 1.0703450484641288, 'OKE'),
#   Text(0.1766439279048436, 1.0857241467031802, 'OKW'),
#   Text(0.10125879622053194, 1.095329473805927, 'OKQ'),
#   Text(0.02796811108899978, 1.0996443901380635, 'KOW'),
#   Text(-0.034243692554438994, 1.0994668569448727, 'KOE'),
#   Text(-0.097686023459648, 1.095653887329681, 'KPR'),
#   Text(-0.17077673219051911, 1.0866624626544932, 'TYU'),
#   Text(-0.22952523843997963, 1.0757872303197649, 'UYT'),
#   Text(-0.2866226123180504, 1.0620016375260335, 'YUT'),
#   Text(-0.3517317105516984, 1.0422498758898349, 'MNB'),
#   Text(-0.41746660978836286, 1.0177040973248614, 'MNV'),
#   Text(-0.4844238358391688, 0.9875897666900291, 'MNC'),
#   Text(-0.5297816837797347, 0.9640183439808132, 'MNX'),
#   Text(-0.5755248904095479, 0.9374279175057024, 'MNZ'),
#   Text(-0.6402441176084893, 0.8944760868059733, 'ZXC'),
#   Text(-0.7014255079320635, 0.8473501382676744, 'XCV'),
#   Text(-0.7528792278408842, 0.8019805909657128, 'CVB'),
#   Text(-0.7954671532752189, 0.7597578614665462, 'VBN'),
#   Text(-0.8363464469158172, 0.7145100564241825, 'BNM'),
#   Text(-0.8759456265505203, 0.6653715197744916, 'NBV'),
#   Text(-0.912786792670697, 0.6138568816311685, 'BVC'),
#   Text(-0.9497845986096011, 0.5548956805058037, 'VCX'),
#   Text(-0.986724211367176, 0.48618446160055806, 'CXZ'),
#   Text(-1.0195448884806653, 0.41295062704026525, 'DCV'),
#   Text(-1.0477613396402734, 0.3349569750807111, 'DER'),
#   Text(-1.070667381291175, 0.25233184230116146, 'FGH'),
#   Text(-1.0862326541707739, 0.173489541509326, 'HUJ'),
#   Text(-1.0950413733208801, 0.10432828339199704, 'GHU'),
#   Text(-1.0990584441816555, 0.04550314574838791, 'YUH'),
#   Text(-1.099970384367965, -0.00807177263009055, 'IJU'),
#   Text(-1.098202520652641, -0.06285875939108418, 'MNK'),
#   Text(-1.093779180136834, -0.1168208247668002, 'OMN'),
#   Text(-1.085948300628761, -0.1752606298103096, 'PLM'),
#   Text(-1.0734288941231085, -0.24031314833283796, 'OKN'),
#   Text(-1.0564246426072166, -0.30654033093903826, 'IJB'),
#   Text(-1.0418728772777321, -0.35284686139034865, 'UHB'),
#   Text(-1.0333932098339083, -0.37695951224126456, 'YGV'),
#   Text(-1.0162299359147062, -0.42104241751965105, 'TFC'),
#   Text(-0.985432425905999, -0.4887974365450558, 'RDX'),
#   Text(-0.9475715106194169, -0.5586664767662692, 'RDS'),
#   Text(-0.9018863430352254, -0.6297626729543025, 'ESX'),
#   Text(-0.8503803840152913, -0.6977486671302253, 'WAX'),
#   Text(-0.7956993975197605, -0.7595146271051602, 'ZAW'),
#   Text(-0.7382072077932027, -0.815506050475509, 'QSX'),
#   Text(-0.6786401964897139, -0.8657063495830458, 'RFB'),
#   Text(-0.6183612449652276, -0.9097413757354635, 'UJO'),
#   Text(-0.55416952298797, -0.9502084717530601, 'GHJ'),
#   Text(-0.4834170426475709, -0.9880829736807921, 'LKJ'),
#   Text(-0.4080101257069277, -1.0215320539858832, 'KJH'),
#   Text(-0.337252037197456, -1.047024862840499, 'JHG'),
#   Text(-0.2729615929724252, -1.065594654998774, 'HGF'),
#   Text(-0.20667002057137043, -1.080410802702856, 'GFD'),
#   Text(-0.129576408404886, -1.0923415008068174, 'FDS'),
#   Text(-0.04163843744528519, -1.0992116450106937, 'DSA'),
#   Text(0.029649177749681746, -1.0996003484260852, 'ASD'),
#   Text(0.09980749074212801, -1.0954626715647413, 'SDF'),
#   Text(0.1872580705523834, -1.0839439169131393, 'DFR'),
#   Text(0.2625228924807181, -1.068214272008925, 'QWE'),
#   Text(0.3235649011272351, -1.0513352247302108, 'WER'),
#   Text(0.3808010705684753, -1.0319837908871938, 'ERT'),
#   Text(0.4438741785840922, -1.0064669460972366, 'TYU'),
#   Text(0.5167651331170738, -0.9710580812672809, 'YUI'),
#   Text(0.590450320292606, -0.9280993585098305, 'UIO'),
#   Text(0.6574438317200175, -0.8819113380228772, 'IOP'),
#   Text(0.7165961551622513, -0.834559734474818, 'LMG'),
#   Text(0.770750265361727, -0.7848210168215602, 'JDH'),
#   Text(0.823173076613878, -0.7296479191624154, 'VCB'),
#   Text(0.8752670355199031, -0.6662639240812914, 'VDF'),
#   Text(0.9238329559657124, -0.5971035667885884, 'BGH'),
#   Text(0.9681195280558355, -0.5222495374789208, 'JKP'),
#   Text(1.0016825425126437, -0.45456801914059697, 'ABC'),
#   Text(1.024763598375152, -0.3998244207714315, 'DBN'),
#   Text(1.0476246957887967, -0.335384103340381, 'NMB'),
#   Text(1.068866450757927, -0.2598547872257735, 'FDT'),
#   Text(1.0825306917721846, -0.19526213501658646, 'TAM'),
#   Text(1.0928670366505842, -0.12506654309834664, 'GQP'),
#   Text(1.0992389870938173, -0.04091025852959932, 'KKK')])

# %%
x=df['s.no']
y=df['percentage']
plt.stem(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %%
plt.hist(df['Marks'],edgecolor='black')
# Out:
# (array([ 3.,  0.,  0.,  2., 11., 11., 16., 17., 22., 17.]),
#  array([101. , 130.7, 160.4, 190.1, 219.8, 249.5, 279.2, 308.9, 338.6,
#         368.3, 398. ]),
#  <a list of 10 Patch objects>)
